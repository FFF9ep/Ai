# %% [markdown]
# <h2>1. Python Basic</h2>

# %% [markdown]
# <h3>1.1 Hello World</h3>

# %% [markdown]
# We will use print() function to print our first python program: hello world.

# %% [markdown]
# Here, 'hello world' is a string, a sequence of characters. In Python, strings are enclosed in single quotes, double quotes, or triple quotes.

# %%
print('hello world')
print("hello world")
# triple quotes allows the string to span multiple lines
print('''hello


world''')
# Out:
# hello world
# hello world
# hello
#
#
# world

# %% [markdown]
# <h3>1.2 Comments</h3>

# %% [markdown]
# Comments are very important while writing a program. They explains the codes in lines for programmers to better understand a program.

# %% [markdown]
# In Python, we use the hash (#) symbol to start writing a comment. Python interpreter ignores comments during execution.
# <li># for one line</li>

# %% [markdown]
# We can have comments that extend up to multiple lines. One way is to use the hash (#) symbol at the beginning of each line. Another way of doing this is to use triple quotes, either ''' or """
# <li>''' ''' for multiple lines</li>

# %%
print("hello world") # this is comment
# Out:
# hello world

# %%
"""
triple quotes for
multiple lines
of comments
"""
print("hello world")
# Out:
# hello world

# %% [markdown]
# <h3>1.3 Packages and modules</h3>

# %% [markdown]
# Python has packages and modules. A module is a file containing Python code. A package is like a directory that contains sub-packages and modules. A library contains multiple modules.

# %% [markdown]
# As our application program grows larger in size with a lot of modules, we place similar modules in one package and different modules in different packages. This makes a project (program) easy to manage and conceptually clear.

# %% [markdown]
# Python package can have sub-packages and modules.

# %% [markdown]
# To use these packages and modules in Python:
# <li>import</li>
# <li>from ... import ...</li>

# %%
import os # import os module
os.getcwd() # get te current working directory
# Out:
# 'G:\\My Drive\\Python Workspace\\Jupyter Notebook\\FGA-AI\\Basic Python'

# %%
from os import getcwd # import getcwd method from os module
getcwd()
# Out:
# 'G:\\My Drive\\Python Workspace\\Jupyter Notebook\\FGA-AI\\Basic Python'

# %% [markdown]
# If a package name is too complex to call, you can give it an alias.

# %%
import platform
platform.platform()
# Out:
# 'Windows-10-10.0.22621-SP0'

# %%
import platform as pf
pf.platform()
# Out:
# 'Windows-10-10.0.22621-SP0'

# %% [markdown]
# <h3>1.4 Variables</h3>

# %% [markdown]
# Variables are containers for storing data values. A variable is a named location used to store data in the memory.

# %% [markdown]
# Declaring and assigning value to a variable:

# %%
a = 1
print(a)
# Out:
# 1

# %% [markdown]
# The value of a variable can be changed later in program.

# %%
a = 2
print(a)
# Out:
# 2

# %% [markdown]
# <h3>1.5 Naming rules and keywords</h3>

# %% [markdown]
# <h4>1.5.1 Naming Rules</h4>

# %% [markdown]
# Variable names should have a combination of letters in lowercase (a to z) or uppercase (A to Z) or digits (0 to 9) or an underscore (_)

# %%
aA9_ = 1

# %% [markdown]
# Create a name that make sense

# %%
wasd = 100
price = 100

# %% [markdown]
# If you want to create a variable name having two words, using underscore to separate them

# %%
number_of_cats = 6

# %% [markdown]
# Don't start a variable name with a digit

# %%
1a = 1 # incorrect variable names
# Out:
#   Cell In[13], line 1
#     1a = 1 # incorrect variable names
#      ^
# SyntaxError: invalid syntax

# %% [markdown]
# <h4>1.5.2 Keywords</h4>

# %% [markdown]
# Keywords are the reserved words in python. They cannot be used as ordinary identifiers and must be spelled exactly.
# There are 35 keywords in python 3.8

# %%
def = 1 # when a variable name is a keyword
# Out:
#   Cell In[14], line 1
#     def = 1 # when a variable name is a keyword
#         ^
# SyntaxError: invalid syntax

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
help("keywords")
# Out:
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               class               from                or
# None                continue            global              pass
# True                def                 if                  raise
# and                 del                 import              return
# as                  elif                in                  try
# assert              else                is                  while
# async               except              lambda              with
# await               finally             nonlocal            yield
# break               for                 not

# %% [markdown]
# <h3>1.6 Switching values</h3>

# %%
a = 1
b = 2
print(a)
print(b)
# Out:
# 1
# 2

# %%
c = a
a = b
b = c
print(a)
print(b)
# Out:
# 2
# 1

# %%
a, b = b, a
print(a)
print(b)
# Out:
# 1
# 2

# %% [markdown]
# <h3>1.7 Execution Order in Python</h3>

# %% [markdown]
# From top to bottom:

# %%
x = 0
print(x+y)
y = 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 2
#       1 x = 0
# ----> 2 print(x+y)
#       3 y = 1
#
# NameError: name 'y' is not defined

# %% [markdown]
# <h3>1.8 Indentation</h3>

# %% [markdown]
# A code block (body of a function, loop, etc) starts with indentation and ends with the first unindented line. The number of space to be intended is up to you, but it must be consistent throughout that block. Indentation makes Python code look neat and clean. This also makes Python code look similar and consistent.

# %%
def func1():
    a = 1
    b = 1

def func2():
       a = 2
       b = 2

# %% [markdown]
# <h3>1.9 Global Variables and Local Variables</h3>

# %%
a = 1 # Global variables

def func(): # define a function
    f = 2 # local variables

c = 3

print(a+c)
# Out:
# 4

# %%
print(a+f)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 print(a+f)
#
# NameError: name 'f' is not defined

# %% [markdown]
# <h3>1.10 Standard I/O</h3>

# %% [markdown]
# To read from standard input, use input() function.

# %% [markdown]
# To write to standard output, use print() function.

# %%
s = input("input: ")
print(s)
# Out:
# input:  yufis
# yufis

# %% [markdown]
# <h3>1.11 Python Basic Functions</h3>

# %% [markdown]
# <h4>1.11.1 help() function</h4>

# %% [markdown]
# The python help function is used to display the documentation of modules, functions, classes, keywords, etc

# %%
help(print)
# Out:
# Help on built-in function print in module builtins:
#
# print(...)
#     print(value, ..., sep=' ', end='\n', file=sys.stdout, flush=False)
#
#     Prints the values to a stream, or to sys.stdout by default.
#     Optional keyword arguments:
#     file:  a file-like object (stream); defaults to the current sys.stdout.
#     sep:   string inserted between values, default a space.
#     end:   string appended after the last value, default a newline.
#     flush: whether to forcibly flush the stream.

# %% [markdown]
# <h4>1.11.2 id() function</h4>

# %% [markdown]
# id function returns the "identity" of an object. This is an integer which is guaranteed to be unique and constant for this object during its lifetime

# %%
b = 1
id(b)
# Out:
# 140728723516320

# %% [markdown]
# <h4>1.11.3 type(function)</h4>

# %% [markdown]
# type function return the type of an object.

# %%
a = 1
type(a)
# Out:
# int

# %% [markdown]
# <h4>1.11.4 del() function</h4>

# %% [markdown]
# del function deletes an object.

# %%
a = 1
del(a)
print(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 3
#       1 a = 1
#       2 del(a)
# ----> 3 print(a)
#
# NameError: name 'a' is not defined

# %% [markdown]
# <h4>1.11.5 len() function</h4>

# %% [markdown]
# len function returns the length (the number of items) of an object.

# %%
len("hello")
# Out:
# 5
